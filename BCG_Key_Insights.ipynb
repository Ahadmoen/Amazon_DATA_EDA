# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %% [markdown]
# ### LOW PRICE BCG ANALYSIS

# %% [markdown]
# ### Stars
# - **Criteria**:
#   - Actual price >= 600
#   - Rating >= 4.0
#   - Rating count between 80,000 and 150,000
#
# | product_id   | actual_price | rating | rating_count       |
# |--------------|--------------|--------|--------------------|
# | B08HDJB6N2   | >= 600       | >= 4.0 | 80,000 - 150,000   |
# | B07BQJ7CJ2   | >= 600       | >= 4.0 | 80,000 - 150,000   |
# | B00NH11KIK   | >= 600       | >= 4.0 | 80,000 - 150,000   |
# | B08HDJB6JX   | >= 600       | >= 4.0 | 80,000 - 150,000   |
# | B07CRL2GY6   | >= 600       | >= 4.0 | 80,000 - 150,000   |
#
# ### Question Mark
# - **Criteria**:
#   - Actual price >= 600
#   - Rating >= 4.0
#   - Rating count <= 4,000
#
# | product_id   | actual_price | rating | rating_count |
# |--------------|--------------|--------|--------------|
# | B09CHHMK7X   | >= 600       | >= 4.0 | <= 4,000     |
# | B09C5KH3K4   | >= 600       | >= 4.0 | <= 4,000     |
# | B09X1LKM7R   | >= 600       | >= 4.0 | <= 4,000     |
# | B00QESSL22   | >= 600       | >= 4.0 | <= 4,000     |
# | B07ZFGT3H4   | >= 600       | >= 4.0 | <= 4,000     |
# | ...          | ...          | ...    | ...          |
#
# ### Cash Cows
# - **Criteria**:
#   - Actual price >= 600
#   - Rating >= 4.0
#   - Rating count >= 150,000
#
# | product_id   | actual_price | rating | rating_count |
# |--------------|--------------|--------|--------------|
# | B07XSMBL2H   | >= 600       | >= 4.0 | >= 150,000   |
# | B005FYNT3G   | >= 600       | >= 4.0 | >= 150,000   |
#
# ### Dogs
# - **Criteria**:
#   - Actual price <= 600
#   - Rating <= 3.5
#   - Rating count >= 5,000
#
# | product_id   | actual_price | rating | rating_count |
# |--------------|--------------|--------|--------------|
# | B07T5DKR5D   | <= 600       | <= 3.5 | >= 5,000     |
# | B08FYFXTY1   | <= 600       | <= 3.5 | >= 5,000     |
# | B00MFPCY5C   | <= 600       | <= 3.5 | >= 5,000     |
# | B07TLPTH84   | <= 600       | <= 3.5 | >= 5,000     |
# | B097JGLJ5G   | <= 600       | <= 3.5 | >= 5,000     |
# | ...          | ...          | ...    | ...          |
#
# ## Summary
# The visualizations categorize products into four quadrants based on their price, rating, and rating count:
# 1. **Stars**: High rating and moderate popularity, priced above 600.
# 2. **Question Mark**: High rating but low popularity, priced above 600.
# 3. **Cash Cows**: High rating and high popularity, priced above 600.
# 4. **Dogs**: Low rating and moderate popularity, priced below 600.
#
# Each category is represented by different products with their respective criteria. The scatter plots provide a clear overview of the distribution and categorization of products based on these factors.

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)

# %% [markdown]
# ## MID PRICE PRODUCT
#
# ### Stars
# - **Criteria**:
#   - Actual price >= 3000
#   - Rating >= 4.0
#   - Rating count between 80,000 and 150,000
#
# | product_id   | actual_price | rating | rating_count       |
# |--------------|--------------|--------|--------------------|
# | B09MT84WV5   | >= 3000      | >= 4.0 | 80,000 - 150,000   |
# | B08TV2P1N8   | >= 3000      | >= 4.0 | 80,000 - 150,000   |
# | B07P7R1C3S   | >= 3000      | >= 4.0 | 80,000 - 150,000   |
# | B092XQ4QNQ   | >= 3000      | >= 4.0 | 80,000 - 150,000   |
# | B07XLML2YS   | >= 3000      | >= 4.0 | 80,000 - 150,000   |
# | B07G3NYLJB   | >= 3000      | >= 4.0 | 80,000 - 150,000   |
#
# ### Question Mark
# - **Criteria**:
#   - Actual price >= 3000
#   - Rating >= 4.0
#   - Rating count <= 4,000
#
# | product_id   | actual_price | rating | rating_count |
# |--------------|--------------|--------|--------------|
# | B08ZGQ7JX   | >= 3000      | >= 4.0 | <= 4,000     |
# | B097BZV2GP6 | >= 3000      | >= 4.0 | <= 4,000     |
# | B089BXK67   | >= 3000      | >= 4.0 | <= 4,000     |
# | B079L2M1F8  | >= 3000      | >= 4.0 | <= 4,000     |
# | B09LD31GF   | >= 3000      | >= 4.0 | <= 4,000     |
# | ...         | ...          | ...    | ...          |
#
# ### Cash Cows
# - **Criteria**:
#   - Actual price >= 3000
#   - Rating >= 4.0
#   - Rating count >= 100,000
#
# | product_id   | actual_price | rating | rating_count |
# |--------------|--------------|--------|--------------|
# | B09MT84WV5   | >= 3000      | >= 4.0 | >= 100,000   |
# | B08TV2P1N8   | >= 3000      | >= 4.0 | >= 100,000   |
# | B07P7R1C3S   | >= 3000      | >= 4.0 | >= 100,000   |
# | B092XQ4QNQ   | >= 3000      | >= 4.0 | >= 100,000   |
#
# ### Dogs
# - **Criteria**:
#   - Actual price <= 3000
#   - Rating <= 3.5
#   - Rating count >= 5,000
#
# | product_id   | actual_price | rating | rating_count |
# |--------------|--------------|--------|--------------|
# | B07XJVYH7L   | <= 3000      | <= 3.5 | >= 5,000     |
# | B085KV6FLH   | <= 3000      | <= 3.5 | >= 5,000     |
# | B07FK8HBGJ   | <= 3000      | <= 3.5 | >= 5,000     |
# | B0994PG1CX   | <= 3000      | <= 3.5 | >= 5,000     |
# | B009LJ2BX   | <= 3000      | <= 3.5 | >= 5,000     |
# | ...          | ...          | ...    | ...          |
#
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# Each category is represented by different products with their respective criteria. The scatter plots provide a clear overview of the distribution and categorization of products based on these factors.

# %% [markdown]
# ## HIGH PRICE PRODUCT
#
# ### Stars
# - **Criteria**:
#   - Actual price >= 30,000
#   - Rating >= 4.0
#   - Rating count between 8,000 and 15,000
#
# | product_id   | actual_price | rating | rating_count       |
# |--------------|--------------|--------|--------------------|
# | B09WRNJ9JG   | >= 30,000    | >= 4.0 | 8,000 - 15,000     |
# | B07WHS7MZ1   | >= 30,000    | >= 4.0 | 8,000 - 15,000     |
#
# ### Question Mark
# - **Criteria**:
#   - Actual price >= 30,000
#   - Rating >= 4.0
#   - Rating count <= 1,000
#
# | product_id   | actual_price | rating | rating_count |
# |--------------|--------------|--------|--------------|
# | B09ZPM4C2C   | >= 30,000    | >= 4.0 | <= 1,000     |
# | B08B3CBFBM   | >= 30,000    | >= 4.0 | <= 1,000     |
# | B09ZPJT8B2   | >= 30,000    | >= 4.0 | <= 1,000     |
# | B09NNHG322   | >= 30,000    | >= 4.0 | <= 1,000     |
# | B08ZRB8P3P   | >= 30,000    | >= 4.0 | <= 1,000     |
#
# ### Cash Cows
# - **Criteria**:
#   - Actual price >= 30,000
#   - Rating >= 4.0
#   - Rating count >= 20,000
#
# | product_id   | actual_price | rating | rating_count |
# |--------------|--------------|--------|--------------|
# | B09UPC8Q0C   | >= 30,000    | >= 4.0 | >= 20,000    |
# | B09RFC46WP   | >= 30,000    | >= 4.0 | >= 20,000    |
# | B09G5P2MT3   | >= 30,000    | >= 4.0 | >= 20,000    |
# | B09J5X1PRF   | >= 30,000    | >= 4.0 | >= 20,000    |
# | B08BF8HF86   | >= 30,000    | >= 4.0 | >= 20,000    |
# | B09FJ7T786   | >= 30,000    | >= 4.0 | >= 20,000    |
# | B09RVQ7YR6   | >= 30,000    | >= 4.0 | >= 20,000    |
# | B07WRDLDRX   | >= 30,000    | >= 4.0 | >= 20,000    |
# | B08VY5T558   | >= 30,000    | >= 4.0 | >= 20,000    |
# | B08GY7FC37   | >= 30,000    | >= 4.0 | >= 20,000    |
#
# ### Dogs
# - **Criteria**:
#   - Actual price <= 30,000
#   - Rating <= 3.5
#   - Rating count >= 5,000
#
# | product_id   | actual_price | rating | rating_count |
# |--------------|--------------|--------|--------------|
# | B08DN94ZRG   | <= 30,000    | <= 3.5 | >= 5,000     |
# | B08D9NDZ1Y   | <= 30,000    | <= 3.5 | >= 5,000     |
#
# ## Summary
# The visualizations categorize products into four quadrants based on their price, rating, and rating count:
# 1. **Stars**: High rating and moderate popularity, priced above 30,000.
# 2. **Question Mark**: High rating but low popularity, priced above 30,000.
# 3. **Cash Cows**: High rating and high popularity, priced above 30,000.
# 4. **Dogs**: Low rating and moderate popularity, priced below 30,000.
#
# Each category is represented by different products with their respective criteria. The scatter plots provide a clear overview of the distribution and categorization of products based on these factors.

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
